# %% [markdown]
# # MegaTetris
# Este Notebook describe los archivos principales del juego de Tetris y cómo ejecutarlo.
#
# ## Archivos del Proyecto
# - `megatetris.py`: Script principal que contiene la lógica del juego.
# - `piezas.py`: Script que define las piezas del Tetris y sus movimientos.
#
# ## Ejecución
# Sigue los pasos descritos en el archivo README para ejecutar el juego localmente.

# %%
# Ejemplo de cómo instalar pygame (si aún no lo tienes instalado)
# !pip install pygame

# %%
# Importa el archivo principal del juego
# !python megatetris.py
